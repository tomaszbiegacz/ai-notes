# %% [markdown]
# # Square polynomial

# %%
import numpy as np
import pandas as pd
import shared.poly as sp
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
data_1 = sp.PolynomialDataset(1, 2)
data_4 = sp.PolynomialDataset(4, 2)

# %% [markdown]
# ## 1 variable

# %%
data_1.model
# Out:
#    0  1  2
# 0  1  7  6

# %%
sp.LinearRegression_check(data_1.X, data_1.y)
# Out:
# a: [66.89565834], b: -98.63852884596466
# manhattan distance: 384296.6388650639

# %%
sp.SGDRegressor_check(data_1.X, data_1.y)
# Out:
# a: [67.68829067], b: [-98.52287742], n_iter: 32
# manhattan distance: 391980.3322246777

# %%
sp.PolynomialRegression_check(data_1.X, data_1.y, degree=2)
# Out:
# a: [7. 6.], b: 0.9999999999995737
# manhattan distance: 5.76760239567875e-09

# %% [markdown]
# ## 4 variable

# %%
data_4.model
# Out:
#    0_0_0_0  0_0_0_1  0_0_0_2  0_0_1_0  0_0_1_1  0_0_2_0  0_1_0_0  0_1_0_1  \
# 0        1        7        6        4        4        8        1        7
#
#    0_1_1_0  0_2_0_0  1_0_0_0  1_0_0_1  1_0_1_0  1_1_0_0  2_0_0_0
# 0        2        1        5        9        7        7        7

# %%
sp.PolynomialRegression_check(data_4.X, data_4.y, degree=2)
# Out:
# a: [5. 1. 4. 7. 7. 7. 7. 9. 1. 2. 7. 8. 4. 6.], b: 0.9999999999990905
# manhattan distance: 1.1081350947961255e-08

# %% [markdown]
# ### learningCurve

# %%
sp.learningCurve(LinearRegression(), data_4.X, data_4.y)

# %%
sp.learningCurve(
    make_pipeline(PolynomialFeatures(degree=2, include_bias=False), LinearRegression()), 
    data_4.X, data_4.y)

# %%
sp.learningCurve(
    make_pipeline(PolynomialFeatures(degree=3, include_bias=False), LinearRegression()), 
    data_4.X, data_4.y)
