# %%
import numpy as np
import pandas as pd
import shared.poly as sp
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
data_6 = sp.PolynomialDataset(6, 8)

# %% [markdown]
# ## 6 variables

# %%
sp.PolynomialRegression_check(data_6.X, data_6.y, degree=8)
# Out:
# a: [3.00043151 3.9993336  8.00042655 ... 9.         5.         2.        ], b: 1.0002975463867188
# manhattan distance: 0.20817347215051996

# %% [markdown]
# ### learningCurve

# %%
sp.learningCurve(LinearRegression(), data_6.X, data_6.y)

# %%
sp.learningCurve(
    make_pipeline(PolynomialFeatures(degree=3, include_bias=False), LinearRegression()), 
    data_6.X, data_6.y)

# %%
sp.learningCurve(
    make_pipeline(PolynomialFeatures(degree=4, include_bias=False), LinearRegression()), 
    data_6.X, data_6.y)

# %%
sp.learningCurve(
    make_pipeline(PolynomialFeatures(degree=6, include_bias=False), LinearRegression()), 
    data_6.X, data_6.y)
